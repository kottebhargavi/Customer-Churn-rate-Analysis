# %%
import pandas as pd
df=pd.read_csv("/content/Sql processing on churn.csv")
df
# Out:
#      customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0    9237-HQITU  Female              0      No         No       2
# 1    9305-CDSKC  Female              0      No         No       8
# 2    8168-UQWWF  Female              0      No         No      11
# 3    7760-OYPDY  Female              0      No         No       2
# 4    7495-OOKFY  Female              1     Yes         No       8
# ..          ...     ...            ...     ...        ...     ...
# 562  1980-KXVPM  Female              1      No         No       3
# 563  0723-DRCLG  Female              1     Yes         No       1
# 564  1122-JWTJW    Male              0     Yes        Yes       1
# 565  6894-LFHLY    Male              1      No         No       1
# 566  8361-LTMKD    Male              1     Yes         No       4
#
#     PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 0            Yes            No     Fiber optic             No  ...
# ...

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  9237-HQITU  Female              0      No         No       2          Yes
# 1  9305-CDSKC  Female              0      No         No       8          Yes
# 2  8168-UQWWF  Female              0      No         No      11          Yes
# 3  7760-OYPDY  Female              0      No         No       2          Yes
# 4  7495-OOKFY  Female              1     Yes         No       8          Yes
#
#   MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0            No     Fiber optic             No  ...               No
# 1           Yes     Fiber optic             No  ...              Yes
# 2           Yes     Fiber optic             No  ...              Yes
# 3            No     Fiber optic             No  ...               No
# 4           Yes     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 567 entries, 0 to 566
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        567 non-null    object
#  1   gender            567 non-null    object
#  2   SeniorCitizen     567 non-null    int64
#  3   Partner           567 non-null    object
#  4   Dependents        567 non-null    object
#  5   tenure            567 non-null    int64
#  6   PhoneService      567 non-null    object
#  7   MultipleLines     567 non-null    object
#  8   InternetService   567 non-null    object
#  9   OnlineSecurity    567 non-null    object
#  10  OnlineBackup      567 non-null    object
#  11  DeviceProtection  567 non-null    object
#  12  TechSupport       567 non-null    object
#  13  StreamingTV       567 non-null    object
#  14  StreamingMovies   567 non-null    object
#  15  Contract          567 non-null    object
# ...

# %%
df.describe()
# Out:
#        SeniorCitizen      tenure  MonthlyCharges  TotalCharges
# count     567.000000  567.000000      567.000000    567.000000
# mean        0.259259    4.343915       83.638360    373.644180
# std         0.438615    3.222584        9.507873    292.806428
# min         0.000000    1.000000       70.050000     70.050000
# 25%         0.000000    1.000000       75.300000     91.075000
# 50%         0.000000    4.000000       80.950000    293.650000
# 75%         1.000000    7.000000       90.675000    577.125000
# max         1.000000   11.000000      110.100000   1222.050000

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
 df.head(10)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  9237-HQITU  Female              0      No         No       2          Yes
# 1  9305-CDSKC  Female              0      No         No       8          Yes
# 2  8168-UQWWF  Female              0      No         No      11          Yes
# 3  7760-OYPDY  Female              0      No         No       2          Yes
# 4  7495-OOKFY  Female              1     Yes         No       8          Yes
# 5  5698-BQJOH  Female              0      No         No       9          Yes
# 6  5919-TMRGD  Female              0      No        Yes       1          Yes
# 7  9191-MYQKX  Female              0     Yes         No       7          Yes
# 8  5299-RULOA  Female              0     Yes        Yes      10          Yes
# 9  0404-SWRVG    Male              0      No         No       3          Yes
#
#   MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# ...

# %%
df.tail()
# Out:
#      customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 562  1980-KXVPM  Female              1      No         No       3
# 563  0723-DRCLG  Female              1     Yes         No       1
# 564  1122-JWTJW    Male              0     Yes        Yes       1
# 565  6894-LFHLY    Male              1      No         No       1
# 566  8361-LTMKD    Male              1     Yes         No       4
#
#     PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 562          Yes           Yes     Fiber optic             No  ...
# 563          Yes           Yes     Fiber optic             No  ...
# 564          Yes            No     Fiber optic             No  ...
# 565          Yes           Yes     Fiber optic             No  ...
# 566          Yes           Yes     Fiber optic             No  ...
#
#     DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 562               No          No          No              No  Month-to-month
# ...

# %%
df.tail(6)
# Out:
#      customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 561  3585-ISXZP  Female              0      No         No       8
# 562  1980-KXVPM  Female              1      No         No       3
# 563  0723-DRCLG  Female              1     Yes         No       1
# 564  1122-JWTJW    Male              0     Yes        Yes       1
# 565  6894-LFHLY    Male              1      No         No       1
# 566  8361-LTMKD    Male              1     Yes         No       4
#
#     PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 561          Yes           Yes     Fiber optic             No  ...
# 562          Yes           Yes     Fiber optic             No  ...
# 563          Yes           Yes     Fiber optic             No  ...
# 564          Yes            No     Fiber optic             No  ...
# 565          Yes           Yes     Fiber optic             No  ...
# 566          Yes           Yes     Fiber optic             No  ...
#
# ...

# %%
df.fillna(0, inplace=True)      # Fill with 0
df.dropna(inplace=True)         # Remove null rows

# %%
df['Churn']
# Out:
# 0      Yes
# 1      Yes
# 2      Yes
# 3      Yes
# 4      Yes
#       ...
# 562    Yes
# 563    Yes
# 564    Yes
# 565    Yes
# 566    Yes
# Name: Churn, Length: 567, dtype: object

# %%
df['Churn'] = df['Churn'].map({'Yes':1, 'No':0})

# %%
df
# Out:
#      customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0    9237-HQITU  Female              0      No         No       2
# 1    9305-CDSKC  Female              0      No         No       8
# 2    8168-UQWWF  Female              0      No         No      11
# 3    7760-OYPDY  Female              0      No         No       2
# 4    7495-OOKFY  Female              1     Yes         No       8
# ..          ...     ...            ...     ...        ...     ...
# 562  1980-KXVPM  Female              1      No         No       3
# 563  0723-DRCLG  Female              1     Yes         No       1
# 564  1122-JWTJW    Male              0     Yes        Yes       1
# 565  6894-LFHLY    Male              1      No         No       1
# 566  8361-LTMKD    Male              1     Yes         No       4
#
#     PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 0            Yes            No     Fiber optic             No  ...
# ...

# %%
df['Churn']
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 562    1
# 563    1
# 564    1
# 565    1
# 566    1
# Name: Churn, Length: 567, dtype: int64

# %%
df.groupby('Contract')['Churn'].mean()
# Out:
# Contract
# Month-to-month    1.0
# One year          1.0
# Name: Churn, dtype: float64

# %%
df['ChargeGroup'] = pd.cut(df['MonthlyCharges'],
                          bins=[0,30,60,90,120],
                          labels=['Low','Medium','High','Very High'])

# %%
df.groupby('ChargeGroup')['Churn'].mean()
# Out:
# /tmp/ipykernel_7126/2809452658.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('ChargeGroup')['Churn'].mean()
# ChargeGroup
# Low          NaN
# Medium       NaN
# High         1.0
# Very High    1.0
# Name: Churn, dtype: float64

# %%
df['TenureGroup'] = pd.cut(df['tenure'],
                          bins=[0,12,24,48,72],
                          labels=['0-1yr','1-2yr','2-4yr','4-6yr'])

# %%
df.groupby('TenureGroup')['Churn'].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_7126/1912237504.py in <cell line: 0>()
# ----> 1 df.groupby('TenureGroup')['Churn'].mean()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9181             raise TypeError("You have to supply one of 'by' and 'level'")
#    9182
# -> 9183         return DataFrameGroupBy(
#    9184             obj=self,
#    9185             keys=by,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1327
#    1328         if grouper is None:
# -> 1329             grouper, exclusions, obj = get_grouper(
#    1330                 obj,
#    1331                 keys,
#
# ...

# %%
df.groupby('InternetService')['Churn'].mean()
# Out:
# InternetService
# DSL            1.0
# Fiber optic    1.0
# Name: Churn, dtype: float64

# %%
import numpy as np
import pandas as pd
df = pd.read_csv("/content/Sql processing on churn.csv")
data_array = df.to_numpy()

# %%
data_array
# Out:
# array([['9237-HQITU', 'Female', 0, ..., 70.7, 151.65, 'Yes'],
#        ['9305-CDSKC', 'Female', 0, ..., 99.65, 820.5, 'Yes'],
#        ['8168-UQWWF', 'Female', 0, ..., 97.85, 1105.4, 'Yes'],
#        ...,
#        ['1122-JWTJW', 'Male', 0, ..., 70.65, 70.65, 'Yes'],
#        ['6894-LFHLY', 'Male', 1, ..., 75.75, 75.75, 'Yes'],
#        ['8361-LTMKD', 'Male', 1, ..., 74.4, 306.6, 'Yes']], dtype=object)

# %%
data_array = np.nan_to_num(data_array)

# %%
monthly = df['MonthlyCharges'].to_numpy()
tenure = df['tenure'].to_numpy()
total = df['TotalCharges'].to_numpy()

# %%
data_array
# Out:
# array([['9237-HQITU', 'Female', 0, ..., 70.7, 151.65, 'Yes'],
#        ['9305-CDSKC', 'Female', 0, ..., 99.65, 820.5, 'Yes'],
#        ['8168-UQWWF', 'Female', 0, ..., 97.85, 1105.4, 'Yes'],
#        ...,
#        ['1122-JWTJW', 'Male', 0, ..., 70.65, 70.65, 'Yes'],
#        ['6894-LFHLY', 'Male', 1, ..., 75.75, 75.75, 'Yes'],
#        ['8361-LTMKD', 'Male', 1, ..., 74.4, 306.6, 'Yes']], dtype=object)

# %%
avg_monthly = np.mean(monthly)
max_monthly = np.max(monthly)
min_monthly = np.min(monthly)

# %%
df
# Out:
#      customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0    9237-HQITU  Female              0      No         No       2
# 1    9305-CDSKC  Female              0      No         No       8
# 2    8168-UQWWF  Female              0      No         No      11
# 3    7760-OYPDY  Female              0      No         No       2
# 4    7495-OOKFY  Female              1     Yes         No       8
# ..          ...     ...            ...     ...        ...     ...
# 562  1980-KXVPM  Female              1      No         No       3
# 563  0723-DRCLG  Female              1     Yes         No       1
# 564  1122-JWTJW    Male              0     Yes        Yes       1
# 565  6894-LFHLY    Male              1      No         No       1
# 566  8361-LTMKD    Male              1     Yes         No       4
#
#     PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 0            Yes            No     Fiber optic             No  ...
# ...

# %%
avg_spend = total / (tenure + 1)

# %%
data_array
# Out:
# array([['9237-HQITU', 'Female', 0, ..., 70.7, 151.65, 'Yes'],
#        ['9305-CDSKC', 'Female', 0, ..., 99.65, 820.5, 'Yes'],
#        ['8168-UQWWF', 'Female', 0, ..., 97.85, 1105.4, 'Yes'],
#        ...,
#        ['1122-JWTJW', 'Male', 0, ..., 70.65, 70.65, 'Yes'],
#        ['6894-LFHLY', 'Male', 1, ..., 75.75, 75.75, 'Yes'],
#        ['8361-LTMKD', 'Male', 1, ..., 74.4, 306.6, 'Yes']], dtype=object)

# %%
charge_group = np.where(monthly < 50, "Low",
                np.where(monthly < 80, "Medium", "High"))

# %%
df
# Out:
#      customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0    9237-HQITU  Female              0      No         No       2
# 1    9305-CDSKC  Female              0      No         No       8
# 2    8168-UQWWF  Female              0      No         No      11
# 3    7760-OYPDY  Female              0      No         No       2
# 4    7495-OOKFY  Female              1     Yes         No       8
# ..          ...     ...            ...     ...        ...     ...
# 562  1980-KXVPM  Female              1      No         No       3
# 563  0723-DRCLG  Female              1     Yes         No       1
# 564  1122-JWTJW    Male              0     Yes        Yes       1
# 565  6894-LFHLY    Male              1      No         No       1
# 566  8361-LTMKD    Male              1     Yes         No       4
#
#     PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 0            Yes            No     Fiber optic             No  ...
# ...

# %%
df['TotalCharges']
# Out:
# 0       151.65
# 1       820.50
# 2      1105.40
# 3       144.15
# 4       633.30
#         ...
# 562     256.25
# 563      74.45
# 564      70.65
# 565      75.75
# 566     306.60
# Name: TotalCharges, Length: 567, dtype: float64

# %%
df['gender'] = df['gender'].map({'Male': 1, 'Female': 0})

# %%
df
# Out:
#      customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0    9237-HQITU       0              0      No         No       2
# 1    9305-CDSKC       0              0      No         No       8
# 2    8168-UQWWF       0              0      No         No      11
# 3    7760-OYPDY       0              0      No         No       2
# 4    7495-OOKFY       0              1     Yes         No       8
# ..          ...     ...            ...     ...        ...     ...
# 562  1980-KXVPM       0              1      No         No       3
# 563  0723-DRCLG       0              1     Yes         No       1
# 564  1122-JWTJW       1              0     Yes        Yes       1
# 565  6894-LFHLY       1              1      No         No       1
# 566  8361-LTMKD       1              1     Yes         No       4
#
#     PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 0            Yes            No     Fiber optic             No  ...
# ...

# %%
df['Contract'] = df['Contract'].astype('category').cat.codes

# %%
df
# Out:
#      customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0    9237-HQITU       0              0      No         No       2
# 1    9305-CDSKC       0              0      No         No       8
# 2    8168-UQWWF       0              0      No         No      11
# 3    7760-OYPDY       0              0      No         No       2
# 4    7495-OOKFY       0              1     Yes         No       8
# ..          ...     ...            ...     ...        ...     ...
# 562  1980-KXVPM       0              1      No         No       3
# 563  0723-DRCLG       0              1     Yes         No       1
# 564  1122-JWTJW       1              0     Yes        Yes       1
# 565  6894-LFHLY       1              1      No         No       1
# 566  8361-LTMKD       1              1     Yes         No       4
#
#     PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 0            Yes            No     Fiber optic             No  ...
# ...

# %%
df['InternetService'] = df['InternetService'].map({
    'DSL': 0,
    'Fiber optic': 1,
    'No': 2
})

# %%
df
# Out:
#      customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0    9237-HQITU       0              0      No         No       2
# 1    9305-CDSKC       0              0      No         No       8
# 2    8168-UQWWF       0              0      No         No      11
# 3    7760-OYPDY       0              0      No         No       2
# 4    7495-OOKFY       0              1     Yes         No       8
# ..          ...     ...            ...     ...        ...     ...
# 562  1980-KXVPM       0              1      No         No       3
# 563  0723-DRCLG       0              1     Yes         No       1
# 564  1122-JWTJW       1              0     Yes        Yes       1
# 565  6894-LFHLY       1              1      No         No       1
# 566  8361-LTMKD       1              1     Yes         No       4
#
#     PhoneService MultipleLines  InternetService OnlineSecurity  ...  \
# 0            Yes            No                1             No  ...
# ...

# %%
df['Churn'] = df['Churn'].map({'Yes':1, 'No':0})

# %%
df
# Out:
#      customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0    9237-HQITU       0              0      No         No       2
# 1    9305-CDSKC       0              0      No         No       8
# 2    8168-UQWWF       0              0      No         No      11
# 3    7760-OYPDY       0              0      No         No       2
# 4    7495-OOKFY       0              1     Yes         No       8
# ..          ...     ...            ...     ...        ...     ...
# 562  1980-KXVPM       0              1      No         No       3
# 563  0723-DRCLG       0              1     Yes         No       1
# 564  1122-JWTJW       1              0     Yes        Yes       1
# 565  6894-LFHLY       1              1      No         No       1
# 566  8361-LTMKD       1              1     Yes         No       4
#
#     PhoneService MultipleLines  InternetService OnlineSecurity  ...  \
# 0            Yes            No                1             No  ...
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df
# Out:
#      customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0    9237-HQITU       0              0      No         No       2
# 1    9305-CDSKC       0              0      No         No       8
# 2    8168-UQWWF       0              0      No         No      11
# 3    7760-OYPDY       0              0      No         No       2
# 4    7495-OOKFY       0              1     Yes         No       8
# ..          ...     ...            ...     ...        ...     ...
# 562  1980-KXVPM       0              1      No         No       3
# 563  0723-DRCLG       0              1     Yes         No       1
# 564  1122-JWTJW       1              0     Yes        Yes       1
# 565  6894-LFHLY       1              1      No         No       1
# 566  8361-LTMKD       1              1     Yes         No       4
#
#     PhoneService MultipleLines  InternetService OnlineSecurity  ...  \
# 0            Yes            No                1             No  ...
# ...

# %%
df['Churn'] = df['Churn'].map({'Yes':1, 'No':0})

# %%
df
# Out:
#      customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0    9237-HQITU       0              0      No         No       2
# 1    9305-CDSKC       0              0      No         No       8
# 2    8168-UQWWF       0              0      No         No      11
# 3    7760-OYPDY       0              0      No         No       2
# 4    7495-OOKFY       0              1     Yes         No       8
# ..          ...     ...            ...     ...        ...     ...
# 562  1980-KXVPM       0              1      No         No       3
# 563  0723-DRCLG       0              1     Yes         No       1
# 564  1122-JWTJW       1              0     Yes        Yes       1
# 565  6894-LFHLY       1              1      No         No       1
# 566  8361-LTMKD       1              1     Yes         No       4
#
#     PhoneService MultipleLines  InternetService OnlineSecurity  ...  \
# 0            Yes            No                1             No  ...
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
plt.figure(figsize=(8,5))

# %%
df['Churn'].value_counts().plot(kind='bar')
plt.title("Churn Count")
plt.xlabel("Churn")
plt.ylabel("Number of Customers")
plt.show()

# %%
df['Churn'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title("Churn Distribution")
plt.ylabel("")
plt.show()

# %%
plt.hist(df['MonthlyCharges'], bins=20)
plt.title("Monthly Charges Distribution")
plt.xlabel("Charges")
plt.ylabel("Frequency")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))

plt.scatter(df['tenure'], df['MonthlyCharges'], alpha=0.5)

plt.title("Tenure vs Monthly Charges")
plt.xlabel("Tenure")
plt.ylabel("Monthly Charges")

plt.show()

# %%
df.groupby('Contract')['Churn'].value_counts().unstack().plot(kind='bar')
plt.title("Contract vs Churn")
plt.xlabel("Contract Type")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.bar(df['Contract'], df['MonthlyCharges'])
plt.xticks(rotation=45)
plt.grid(True)

# %%
plt.savefig("churn_chart.png")

# %%
df.groupby('InternetService')['Churn'].value_counts().unstack().plot(kind='bar')
plt.title("Internet Service vs Churn")
plt.show()

# %%
pip install seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set_style("whitegrid")

# %%
sns.countplot(x='Churn', data=df)
plt.title("Churn Count")
plt.show()

# %%
sns.countplot(x='Contract', hue='Churn', data=df)
plt.title("Contract vs Churn")
plt.show()

# %%
sns.countplot(x='InternetService', hue='Churn', data=df)
plt.title("Internet Service vs Churn")
plt.xticks(rotation=30)
plt.show()

# %%
sns.histplot(df['MonthlyCharges'], kde=True)
plt.title("Monthly Charges Distribution")
plt.show()

# %%
sns.boxplot(x='Churn', y='MonthlyCharges', data=df)
plt.title("Charges vs Churn")
plt.show()

# %%
sns.scatterplot(x='tenure', y='MonthlyCharges', hue='Churn', data=df)
plt.title("Tenure vs Charges")
plt.show()

# %%
corr = df.corr(numeric_only=True)

sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %%
sns.pairplot(df, hue='Churn')

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='Contract', hue='Churn', data=df)
plt.xticks(rotation=45)
# Out:
# ([0, 1], [Text(0, 0, '0'), Text(1, 0, '1')])

# %%
df
# Out:
#      customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0    9237-HQITU       0              0      No         No       2
# 1    9305-CDSKC       0              0      No         No       8
# 2    8168-UQWWF       0              0      No         No      11
# 3    7760-OYPDY       0              0      No         No       2
# 4    7495-OOKFY       0              1     Yes         No       8
# ..          ...     ...            ...     ...        ...     ...
# 562  1980-KXVPM       0              1      No         No       3
# 563  0723-DRCLG       0              1     Yes         No       1
# 564  1122-JWTJW       1              0     Yes        Yes       1
# 565  6894-LFHLY       1              1      No         No       1
# 566  8361-LTMKD       1              1     Yes         No       4
#
#     PhoneService MultipleLines  InternetService OnlineSecurity  ...  \
# 0            Yes            No                1             No  ...
# ...

# %%
import pandas as pd
df.to_excel("output.xlsx", index=False)

# %%
from google.colab import files

files.download("output.xlsx")
